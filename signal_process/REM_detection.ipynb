# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#REM-detection" data-toc-modified-id="REM-detection-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>REM detection</a></span></li></ul></div>

# %% [markdown]
# # REM detection

# %%
import misleep

# %%
data = misleep.load_mat(
    r'E:\workplace\EEGProcessing\00_DATA\nice_data\20240114_male2_nf.mat')

# %%
print(data.channels)
rem_crop = data.crop([1718, 1749])
# Out:
# ['EEG_F', 'EEG_P', 'F_P_DIFF', 'EMG_DIFF', 'REF']

# %%
fig, ax = misleep.plot_signals(rem_crop.signals, rem_crop.sf, rem_crop.channels)
