# %%
from misleep import load_mat
# Out:
# e:\workplace\scripts\signal_process

# %%
data = load_mat(r'E:\workplace\EEGProcessing\00_DATA\EEG_TM\20240513_190000\20240513_190000.mat')

# %%
from scipy.signal import welch

# %%
ch_data = data.signals[0]
sf = data.sf[0]
nperseg = 5*sf

# %%
sf
# Out:
# 200.0

# %%
F, P = welch(ch_data, sf)

# %%
import pandas as pd
import numpy as np
pd.DataFrame(np.array([F, P]).T, columns=['F' ,'P']).to_csv(r'E:\workplace\EEGProcessing\00_DATA\EEG_TM\20240513_190000\aaa.csv')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(F, P)
plt.title('EEG')
# Out:
# Text(0.5, 1.0, 'EEG')
