# %%
from misleep import load_mat
# Out:
# e:\workplace\scripts\signal_process

# %%
data = load_mat(r'\\172.16.41.188\wangxueqiang\EEG_data\TechMan\20240520_100000.mat')

data.filter(['EMG_DIFF'], btype='highpass', low=10)
data.filter(['EEG'], btype='highpass', low=10)
ch_data = data.signals[2]
sf = data.sf[2]
nperseg = 5*sf

F, P = welch(ch_data, sf)

plt.plot(F, P)
plt.title("EEG 10 Hz highpass")
plt.show()

ch_data = data.signals[3]
sf = data.sf[3]
nperseg = 5*sf

F, P = welch(ch_data, sf)

plt.plot(F, P)
plt.title("EMG_DIFF 10 Hz highpass")
plt.show()

# %%
from scipy.signal import welch

# %%
data.channels
# Out:
# ['EEG', 'EMG_DIFF', 'EMG_DIFF_highpass_5']

# %%
sf
# Out:
# 500.0

# %%
import pandas as pd
import numpy as np
pd.DataFrame(np.array([F, P]).T, columns=['F' ,'P']).to_csv(r'E:\workplace\EEGProcessing\00_DATA\EEG_TM\20240513_190000\aaa.csv')

# %%
import matplotlib.pyplot as plt

# %%
# plt.ylim(0, 1e-5)
# plt.title('EEG')
